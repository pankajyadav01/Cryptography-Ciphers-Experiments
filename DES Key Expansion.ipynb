# %%
Pankaj Yadav (15-CSU-145)

# %% [markdown]
# # DES Key-Generation

# %%
parity=[[57,49,41,33,25,17,9,1],
       [58,50,42,34,26,18,10,2],
       [59,51,43,35,27,19,11,3],
       [60,52,44,36,63,55,47,39],
       [31,23,15,7,62,54,46,38],
       [30,22,14,6,61,53,45,37],
       [29,21,13,5,28,20,12,4]]

compression=[[14,17,11,24,1,5,3,28],
            [15,6,21,10,23,19,12,4],
            [26,8,16,7,27,20,13,2],
            [41,52,31,37,47,55,30,40],
            [51,45,33,48,44,49,49,56],
            [34,53,46,42,50,36,29,32]]

key='AABB09182736CCDD'

def lshift(key,rno):
    temp1=key[:28]
    temp2=key[28:]
    temp11=temp1[rno:] + temp1[:rno]
    temp22=temp2[rno:] + temp2[:rno]
    temp=temp11+temp22
    return temp

print('Initial Key(64bit) :\t\t\t'+key)
key_int = int(key, 16)
key_bin = bin(key_int)[2:]
str_key_bin=str(key_bin)
# key_hex = key_int + 0x200
# print(hex(key_hex)[2:])
print('Initial Key in Binary :\t\t\t'+str_key_bin)

key1=''
for i in range(7):
    for j in range(8):
        key1+=str_key_bin[parity[i][j]-1]

print('Binary Key after Parity Drop :\t\t'+key1)
key1_int = int(key1, 2)
key1_hex = key1_int + 0x200
print('Key(Hex) after Parity Drop(56bit) :\t'+ hex(key1_hex)[2:])
round_no=1
n=2
a1=[]
round_keys=[]
for i in range(16):
    if (round_no==1 or round_no==2 or round_no==9 or round_no==16):
        n=1
    else:
        n=2
    key1 = lshift(key1,n)
    round_no+=1
#     print('\t\t\t\t\t'+key1)
    for j in range(6):
        for k in range(8):
            a1+=key1[compression[j][k]-1]
    a=''.join(a1)
    round_keys.append(a)
    del a
    a1=[]
print('\n\n')
for i in range(16):
    print('Binary Key for round '+str(i+1)+' is :'+str(round_keys[i]))
    
print('\n\n')
for i in range(16):
    round_key_int = int(round_keys[i], 2)
    round_hex = round_key_int + 0x200
    print('Key(Hex) for round '+str(i+1)+' is :'+ hex(round_hex)[2:])
# Out:
# Initial Key(64bit) :			AABB09182736CCDD
# Initial Key in Binary :			1010101010111011000010010001100000100111001101101100110011011101
# Binary Key after Parity Drop :		11000011110000000011001110100011001111110000110011111010
# Key(Hex) after Parity Drop(56bit) :	c3c033a33f0efa
#
#
#
# Binary Key for round 1 is :000110010100110011010000011100101101111010001100
# Binary Key for round 2 is :010001010110100001011000000110101011111011001110
# Binary Key for round 3 is :000001101110110110100100101011001111011110110101
# Binary Key for round 4 is :110110100010110100000011001010110110111011100011
# Binary Key for round 5 is :011010011010011000101001111111101100100100010011
# Binary Key for round 6 is :110000011001010010001110100001110100011101011110
# Binary Key for round 7 is :011100001000101011010010110111011011000111000000
# Binary Key for round 8 is :001101001111100000100010111100001100011001101101
# Binary Key for round 9 is :100001001011101101000100011100111101111011001100
# Binary Key for round 10 is :000000100111011001010111000010001011011110111111
# Binary Key for round 11 is :011011010101010101100000101011110111111010100101
# Binary Key for round 12 is :110000101100000111101001011010100100100111110011
# Binary Key for round 13 is :100110011100001100010011100101111100100100011111
# Binary Key for round 14 is :001001010001101110001011110001110001011111010000
# Binary Key for round 15 is :001100110011000011000101110110011010000101101101
# Binary Key for round 16 is :000110000001110001011101011101011100011001101101
#
#
#
# Key(Hex) for round 1 is :194cd072e08c
# Key(Hex) for round 2 is :4568581ac0ce
# Key(Hex) for round 3 is :6eda4acf9b5
# Key(Hex) for round 4 is :da2d032b70e3
# Key(Hex) for round 5 is :69a629fecb13
# Key(Hex) for round 6 is :c1948e87495e
# Key(Hex) for round 7 is :708ad2ddb3c0
# Key(Hex) for round 8 is :34f822f0c86d
# Key(Hex) for round 9 is :84bb4473e0cc
# Key(Hex) for round 10 is :2765708b9bf
# Key(Hex) for round 11 is :6d5560af80a5
# Key(Hex) for round 12 is :c2c1e96a4bf3
# Key(Hex) for round 13 is :99c31397cb1f
# Key(Hex) for round 14 is :251b8bc719d0
# Key(Hex) for round 15 is :3330c5d9a36d
# Key(Hex) for round 16 is :181c5d75c86d
